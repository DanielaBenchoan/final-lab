# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Daniela Benchoan
#
# I aspire to be a Data Scientist

# %% [markdown]
# ## *I am interested in Data Science because I love to handle and structure data and information. I would also love to help with common interest problems of where I live.*

# %% [markdown]
# ### To explain, my code will be doing an addition of numbers.

# %%
one = 1
two = 2
print(one + two)
# Out:
# 3

# %% [markdown]
# I have three cats, and their names are:
# - Ron
# - Baloo
# - Jin
#
# ---
#
# Ron is an orange cat, pretty much like this one
# ![orange cat.jfif](attachment:d1120f06-741f-4e4d-8039-ac670d7b1da0.jfif)
# Baloo is a black cat, he is tiny because he is still young. He looks like this
# ![black cat.jpg](attachment:b3864b8a-07e6-4942-a368-7b7272116fb9.jpg)
# And Jin is a beautiful tricolor cat, but with more slightly pastel colors, like this one:
# ![pastel cat 1.jpg](attachment:02077993-2011-40b7-8061-cf8552add9da.jpg)
